# %% [markdown]
# # Chapter 14: From Python to Data Thinking

# %% [markdown]
# ## Problem 1: What Is the Core Pattern Behind All Programming?

# %% [markdown]
# ## Problem 2: What Has Pure Python Been Doing So Far?

# %% [markdown]
# ## Problem 3: Why Does Python Have Modules and a Standard Library?

# %% [markdown]
# ## Problem 4: What Are the Limits of Pure Python for Data?

# %% [markdown]
# ## Problem 5: Why Does Pandas Exist?

# %% [markdown]
# ## Problem 6: Why Does Local Development Matter for Data Work?

# %% [markdown]
# ## Problem 7: What Changes in Part 2?

# %% [markdown]
# ## End-of-Chapter Direction
