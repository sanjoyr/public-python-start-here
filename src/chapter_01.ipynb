# %% [markdown]
# # Chapter 1: First Steps with Python

# %% [markdown]
# ## Problem 1: How Do I Know Python Is Working?

# %%
print("Hello, World")

# %% [markdown]
# ## Problem 2: Can Python Display a Real Data Value?

# %%
print("India Total Population (2011): 1,210,854,977")

# %% [markdown]
# ## Problem 3: Where Should I Write and Run Python Code?

# %% [markdown]
# ## Problem 4: How Do I Start Using Google Colaboratory?

# %%
print("Python is my first programming language")

# %%
print("I am learning Python with real data")

# %% [markdown]
# ## Problem 5: What Happens to My Notebook and Code?

# %% [markdown]
# ## Problem 6: Where Does My Code Run?

# %% [markdown]
# ## Problem 7: How Should I Use Notebooks Throughout This Book?

# %% [markdown]
# ## End-of-Chapter Direction
