# %% [markdown]
# # Chapter 34: Why Features Matter Most
#
# ⚠️ **DO NOT SKIP THIS CELL**
#
# ## Run the Next cell.
# ### Before executing any other cell you must run the next cell to set up the project folder environment.

# %%
from pathlib import Path

try:
    from google.colab import drive
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    drive.mount("/content/drive")
    PROJECT_ROOT = Path("/content/drive/MyDrive/DataScience/census-education-analysis")
else:
    PROJECT_ROOT = Path.cwd().parent

DATA_DIR = PROJECT_ROOT / "data"
RAW_DIR = DATA_DIR / "raw"
STAGING_DIR = DATA_DIR / "staging"
PROCESSED_DIR = DATA_DIR / "processed"
OUTPUTS_DIR = PROJECT_ROOT / "outputs"

PROJECT_ROOT

# %% [markdown]
# ## Problem 1: What Dataset Are We Starting From?

# %%
import pandas as pd

input_path = OUTPUTS_DIR / "india_model_prep.csv"
df = pd.read_csv(input_path)

df.head()

# %% [markdown]
# ## Problem 2: What Is a Feature in Practical Terms?

# %% [markdown]
# ## Problem 3: Why Is Feature Selection a Decision, Not a Technical Step?

# %% [markdown]
# ## Problem 4: Feature Engineering vs Feature Invention

# %% [markdown]
# ## Problem 5: How Does Our Census Dataset Make This Concrete?

# %% [markdown]
# ## Problem 6: What Are Proxy Variables, and Why Are They Dangerous?

# %% [markdown]
# ## Problem 7: Designing Features With Intent (Not With Code)

# %%
feature_df = df[[
    "state_name",
    "total_persons",
    "literacy_rate",
    "gender_literacy_gap",
    "priority_flag"
]].copy()

# %% [markdown]
# ## Problem 8: Why Models Learn Only What Features Allow

# %% [markdown]
# ## Problem 9: Freezing the Feature Set for Modeling

# %%
output_path = OUTPUTS_DIR / "india_feature_ready.csv"
feature_df.to_csv(output_path, index=False)

output_path

# %% [markdown]
# ## End-of-Chapter Direction
