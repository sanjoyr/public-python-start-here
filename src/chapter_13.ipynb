# %% [markdown]
# # Chapter 13: The Debugging Mindset

# %% [markdown]
# ## Problem 1: What Does It Mean When Python Shows an Error?

# %%
population = "91276115"
population / 2

# %% [markdown]
# ## Problem 2: How Do I Read a Traceback?

# %% [markdown]
# ## Problem 3: Fixing Errors by Checking Assumptions

# %%
population = "91276115"
type(population)

# %%
population = int(population)
population / 2

# %% [markdown]
# ## Problem 4: What If Data Is Missing or Invalid?

# %%
population = None
population > 50000000

# %%
population = None

if population is None:
    print("Population data missing")
else:
    print(population > 50000000)

# %% [markdown]
# ## Problem 5: Handling Errors Without Crashing

# %%
population = "unknown"

try:
    population = int(population)
    print(population > 50000000)
except ValueError:
    print("Invalid population value")

# %% [markdown]
# ## Problem 6: When Should I Raise My Own Errors?

# %%
def check_population(population):
    if population is None:
        raise ValueError("Population cannot be missing")
    return population > 50000000

# %% [markdown]
# ## Problem 7: Debugging as a Habit, Not a Panic

# %% [markdown]
# ## End-of-Chapter Direction
