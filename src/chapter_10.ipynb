# %% [markdown]
# # Chapter 10: Defensive Programming

# %% [markdown]
# ## Problem 1: What Does “Bad Data” Look Like?

# %% [markdown]
# ## Problem 2: How Do We Detect Missing Values?

# %%
population = None

if population is None:
    print("Population data is missing")

# %% [markdown]
# ## Problem 3: How Do We Guard Against Empty or Invalid Text?

# %%
population = ""

if population == "":
    print("Population value is empty")

# %%
population = "91276115"

if population.isdigit():
    population = int(population)
else:
    print("Invalid population value")

# %% [markdown]
# ## Problem 4: Why Do Errors Happen in Programs?

# %% [markdown]
# ## Problem 5: How Do We Prevent Crashes with `try` and `except`?

# %%
try:
    population = int("not_a_number")
    result = population / 2
except ValueError:
    print("Population data is invalid")

# %% [markdown]
# ## Problem 6: Combining Validation with Error Handling

# %%
def safe_half_population(value):
    if value is None or value == "":
        return "Missing data"

    try:
        value = int(value)
    except ValueError:
        return "Invalid population"

    if value <= 0:
        return "Invalid population"

    return value / 2

# %%
safe_half_population("91276115")
safe_half_population(None)
safe_half_population("")
safe_half_population("abc")

# %% [markdown]
# ## Problem 7: Why Defensive Programming Matters in Data Science

# %% [markdown]
# ## End-of-Chapter Direction
