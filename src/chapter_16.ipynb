# %% [markdown]
# # Chapter 16: Setting Up a Real Data Environment
#
# ⚠️ **DO NOT SKIP THIS CELL**
#
# ## Run the Next cell.
# ### Before executing any other cell you must run the next cell to set up the project folder environment.

# %%
from pathlib import Path

try:
    from google.colab import drive
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    drive.mount("/content/drive")
    PROJECT_ROOT = Path("/content/drive/MyDrive/DataScience/census-education-analysis")
else:
    PROJECT_ROOT = Path.cwd().parent

DATA_DIR = PROJECT_ROOT / "data"
RAW_DIR = DATA_DIR / "raw"
STAGING_DIR = DATA_DIR / "staging"
PROCESSED_DIR = DATA_DIR / "processed"
OUTPUTS_DIR = PROJECT_ROOT / "outputs"

PROJECT_ROOT

# %% [markdown]
# ## Companion Repository (Required from This Chapter Onward)

# %% [markdown]
# ## Problem 1: How Do Professionals Keep Projects Clean and Repeatable?

# %% [markdown]
# ## Problem 2: Why Should I Use the Terminal Instead of GUI Tools?

# %% [markdown]
# ## Problem 3: Why Can’t I Install Python Packages Globally?

# %% [markdown]
# ## Problem 4: How Do I Know Python Is Working Correctly?

# %% [markdown]
# ## Problem 5: Where Do My Project Dependencies Live?

# %% [markdown]
# ## Problem 6: How Do Notebooks Fit into a Professional Setup?

# %% [markdown]
# ## Problem 7: How Do Professionals Track Changes Safely?

# %% [markdown]
# ## Problem 8: Why Is GitHub Necessary in Addition to Git?

# %% [markdown]
# ## Problem 9: How Do I Configure Git Once on My Machine?

# %% [markdown]
# ## Problem 10: How Do I Connect My Machine to GitHub Securely?

# %% [markdown]
# ## Problem 11: How Do I Push a Project to GitHub?

# %% [markdown]
# ## Problem 12: What Is the Daily Professional Working Cycle?

# %% [markdown]
# ## Problem 13: What If Something Breaks?

# %% [markdown]
# ## Problem 14: What If I Cannot Set Up a Local Environment Right Now?

# %% [markdown]
# ## Problem 15: Why Must Every Notebook Start by Locating the Project Root?

# %%
from pathlib import Path

# --
# Step 1: Detect if running inside Google Colaboratory
# --
try:
    from google.colab import drive
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

# --
# Step 2: Mount Google Drive only if in Google Colaboratory
# --
if IN_COLAB:
    drive.mount("/content/drive")
    PROJECT_ROOT = Path("/content/drive/MyDrive/DataScience/census-education-analysis")
else:
    # Local Jupyter: notebooks live inside src/
    PROJECT_ROOT = Path.cwd().parent

# --
# Step 3: Define standard project paths
# --
DATA_DIR = PROJECT_ROOT / "data"
RAW_DIR = DATA_DIR / "raw"
STAGING_DIR = DATA_DIR / "staging"
PROCESSED_DIR = DATA_DIR / "processed"
OUTPUTS_DIR = PROJECT_ROOT / "outputs"

PROJECT_ROOT

# %%
import pandas as pd

df = pd.read_excel(STAGING_DIR / "education" / "west_bengal.xlsx")

# %% [markdown]
# ## Problem 16: How Should Every Chapter in Part 2 Be Worked as a Professional Session?

# %% [markdown]
# ## Before You Start (Mandatory for Every Chapter)

# %% [markdown]
# ## During the Chapter (How You Should Work)

# %% [markdown]
# ## Before You End (Mandatory for Every Chapter)

# %% [markdown]
# ## If You Cannot Complete a Chapter Fully

# %% [markdown]
# ## This Is the Contract for Part 2

# %% [markdown]
# ## End-of-Chapter Direction
