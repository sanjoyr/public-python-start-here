# %% [markdown]
# # Chapter 11: Working with Files

# %% [markdown]
# ## Problem 1: Where Does Real Data Live?

# %% [markdown]
# ## Problem 2: How Do We Create a File Using Python?

# %%
with open("eastern_states.txt", "w") as file:
    file.write("West Bengal\n")
    file.write("Odisha\n")
    file.write("Bihar\n")
    file.write("Jharkhand\n")
    file.write("Assam\n")

# %% [markdown]
# ## Problem 3: How Does Python Know Where a File Is?

# %%
open("eastern_states.txt")

# %%
with open("eastern_states.txt", "r") as file:
    content = file.read()
    print(content)

# %% [markdown]
# ## Problem 4: What Happens If the File Name Is Wrong?

# %%
with open("Eastern_States.txt", "r") as file:
    print(file.read())

# %% [markdown]
# ## Problem 5: How Do Programs Handle Missing Files Safely?

# %%
try:
    with open("missing_file.txt", "r") as file:
        print(file.read())
except FileNotFoundError:
    print("File not found. Please check the file name.")

# %% [markdown]
# ## Problem 6: Why Does Python Make Us Open and Close Files?

# %%
with open("eastern_states.txt", "r") as file:
    for line in file:
        print(line.strip())

# %% [markdown]
# ## Problem 7: Why Are We Using Text Files Instead of Excel?

# %% [markdown]
# ## Problem 8: Why File Handling Matters for Data Science

# %% [markdown]
# ## End-of-Chapter Direction
