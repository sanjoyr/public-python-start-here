# %% [markdown]
# # Chapter 3: Understanding Data Types

# %% [markdown]
# ## Problem 1: Can Python Tell Numbers and Text Apart?

# %%
state_name = "West Bengal"
population = 91276115

# %%
print(type(state_name))
print(type(population))

# %% [markdown]
# ## Problem 2: Why Does Data Type Matter?

# %%
print(population + 1000000)

# %%
print(state_name + 1000000)

# %% [markdown]
# ## Problem 3: What Data Types Will I Use First?

# %%
state_name = "West Bengal"
print(state_name)

# %%
population = 91276115
print(population)

# %%
population_growth_rate = 1.32
print(population_growth_rate)

# %% [markdown]
# ## Problem 4: Does Python Need Me to Declare the Data Type?

# %%
x = 10
y = "India"
z = 2.5

# %% [markdown]
# ## Problem 5: Can the Same Data Look Different Based on Type?

# %%
population_text = "91276115"
population_number = 91276115

# %%
print(population_text + population_text)
print(population_number + population_number)

# %% [markdown]
# ## Problem 6: How Do I Check Data Types While Working?

# %%
print(type(population))
print(type(state_name))

# %% [markdown]
# ## Problem 7: What Are Data Type Hints and Why Mention Them?

# %%
population: int = 91276115
state_name: str = "West Bengal"

# %% [markdown]
# ## End-of-Chapter Direction
