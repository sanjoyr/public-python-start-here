# %% [markdown]
# # Chapter 2: Variables That Remember

# %% [markdown]
# ## Problem 1: Can Python Remember a Population Number?

# %%
india_population = 1210854977

# %%
print(india_population)

# %%
india_population = 1_210_854_977  # Python reads this as 1210854977

# %% [markdown]
# ## Problem 2: Why Do We Use Variables Instead of Direct Numbers?

# %%
print("India Population:", india_population)

# %% [markdown]
# ## Problem 3: Can Python Store More Than One Value?

# %%
india_population = 1210854977
number_of_states = 35

# %%
print("Population:", india_population)
print("Number of States:", number_of_states)

# %% [markdown]
# ## Problem 4: How Should I Name Variables?

# %%
total_population = 1210854977
states = 35
_population = 1210854977

# %%
1population = 1210854977
total population = 1210854977
for = 10

# %% [markdown]
# ## Problem 5: How Do Professionals Name Variables?

# %%
india_population
number_of_states
total_households

# %%
x = 1210854977
n = 35

# %% [markdown]
# ## Problem 6: What Are Reserved Words and Why Can’t I Use Them?

# %%
if = 10

# %% [markdown]
# ## Problem 7: Can Variables Change?

# %%
india_population = 1210854977
print(india_population)

india_population = 1210854977 + 1000000
print(india_population)

# %% [markdown]
# ## End-of-Chapter Direction
