# %% [markdown]
# # Chapter 6: Working with Collections

# %% [markdown]
# ## Problem 1: Why Is One Variable Not Enough?

# %% [markdown]
# ## Problem 2: How Do We Group Multiple Values in Python?

# %%
state_populations = [91276115, 104099452, 112374333]

# %% [markdown]
# ## Problem 3: How Do We Access Individual Values?

# %%
state_populations[0]

# %%
state_populations[1]
state_populations[2]

# %% [markdown]
# ## Problem 4: How Many Values Are in the List?

# %%
len(state_populations)

# %% [markdown]
# ## Problem 5: Using Lists to Answer a Real Question

# %%
total_population = (
    state_populations[0] +
    state_populations[1] +
    state_populations[2]
)

average_population = total_population / len(state_populations)

print(average_population)

# %% [markdown]
# ## Problem 6: Lists Can Hold More Than Numbers

# %%
state_names = ["West Bengal", "Bihar", "Maharashtra"]

# %% [markdown]
# ## Problem 7: Are Lists the Same as Arrays?

# %% [markdown]
# ## Problem 8: Common Beginner Mistake to Avoid

# %%
pop1 = 91276115
pop2 = 104099452
pop3 = 112374333

# %%
state_populations = [91276115, 104099452, 112374333]

# %% [markdown]
# ## End-of-Chapter Direction
