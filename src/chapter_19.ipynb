# %% [markdown]
# # Chapter 19: Reading Census Education Excel Files Carefully
#
# ⚠️ **DO NOT SKIP THIS CELL**
#
# ## Run the Next cell.
# ### Before executing any other cell you must run the next cell to set up the project folder environment.

# %%
from pathlib import Path

try:
    from google.colab import drive
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    drive.mount("/content/drive")
    PROJECT_ROOT = Path("/content/drive/MyDrive/DataScience/census-education-analysis")
else:
    PROJECT_ROOT = Path.cwd().parent

DATA_DIR = PROJECT_ROOT / "data"
RAW_DIR = DATA_DIR / "raw"
STAGING_DIR = DATA_DIR / "staging"
PROCESSED_DIR = DATA_DIR / "processed"
OUTPUTS_DIR = PROJECT_ROOT / "outputs"

PROJECT_ROOT

# %% [markdown]
# ## Problem 1: Which Education File Do We Start With?

# %% [markdown]
# ## Problem 2: Where Does Real Data Actually Start in the Excel File?

# %% [markdown]
# ## Problem 3: What Are the Key Columns We Care About?

# %% [markdown]
# ## Problem 4: What Does One Logical Row Represent?

# %% [markdown]
# ## Problem 5: How Do I Load the File into Python Without Losing Context?

# %%
import pandas as pd

edu_path = STAGING_DIR / "education" / "west_bengal.xlsx"
edu_df = pd.read_excel(edu_path, header=None)

edu_df.head(12)

# %% [markdown]
# ## Problem 6: How Do I Verify That Python Matches Excel?

# %%
edu_df.shape

# %%
edu_df.iloc[7:15]

# %% [markdown]
# ## Problem 7: What Must Be True Before Any Filtering or Cleaning?

# %% [markdown]
# ## Problem 8: What Does “Never Code Before Understanding Data” Mean Here?

# %% [markdown]
# ## End-of-Chapter Direction
